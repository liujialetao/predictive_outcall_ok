# %%
import pandas as pd
import os

# %%
data1 = pd.read_csv('solution1_2000_test1.csv', index_col=0)
data3 = pd.read_csv('solution3_2000_test1.csv', index_col=0)

# %%
data1
# Out:
#     average_artificial_time_cal  average_dial_interval  average_idle_time  \
# 0                     28.309704              11.785051          20.506001
# 1                     26.745718              12.072652          20.766284
# 2                     26.561796              11.958518          22.403302
# 3                     26.523136              12.150881          21.801653
# 4                     26.406367              12.297291          21.681613
# ..                          ...                    ...                ...
# 85                    27.463220              14.199984          33.642905
# 86                    27.688320              13.909536          34.426984
# 87                    27.198918              14.148913          34.088936
# 88                    27.466619              13.783032          34.693402
# 89                    27.996576              14.144620          33.804283
#
#     busy_ration  call_num  customer_num  loss_ration  max_wait_time  \
# ...

# %%
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

x2 = data1_2.loss_ration
y2 = data1_2.average_idle_time
plt.scatter(x2, y2, s=20, c='green', marker='*', label='Concurrency_num=2')

x3 = data1_3.loss_ration
y3 = data1_3.average_idle_time

plt.scatter(x3, y3, s=20, c='red', label='Concurrency_num=3')

x4 = data1_4.loss_ration
y4 = data1_4.average_idle_time
plt.scatter(x4, y4, s=20, c='blue', marker='*', label='Concurrency_num=4')

plt.legend()
plt.title('result')
plt.xlabel('call_loss_ration')
plt.ylabel('seat_wait_time')
plt.show()

# %%
plt.style.use('fivethirtyeight')

x1 = data1.loss_ration
y1 = data1.average_idle_time
x3 = data2.loss_ration
y3 = data2.average_idle_time

plt.scatter(x1, y1, s=20, c='green', marker='*',label='old_algorithm')
plt.scatter(x3, y3, s=20, c='red', marker='.',label='new_algorithm')
plt.legend()
plt.title('result')
plt.xlabel('call_loss_ration')
plt.ylabel('wait_time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ca5d807956ca> in <module>()
# ----> 1 plt.style.use('fivethirtyeight')
#       2
#       3 x1 = data1.loss_ration
#       4 y1 = data1.average_idle_time
#       5 x3 = data2.loss_ration
#
# NameError: name 'plt' is not defined

# %%
plt.style.use('fivethirtyeight')
# data1.loss_ration,data1.busy_ration1
call_loss = data1.loss_ration
busy_ration = data1.average_dial_interval
call_loss2 = data2.loss_ration
busy_ration2 = data2.average_dial_interval

plt.scatter(call_loss, busy_ration, s=20, c='green', marker='*',label='old_algorithm')
plt.scatter(call_loss2, busy_ration2, s=20, c='red', marker='.',label='new_algorithm')
plt.legend()
plt.title('result')
plt.xlabel('call_loss_ration')
plt.ylabel('average_dial_interval')
plt.show()
